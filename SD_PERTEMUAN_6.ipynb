# %% [markdown]
# Implementasi Bubble Sort

# %%
def bubble_sort(arr):
  n = len(arr)
  for i in range(n - 1):
      for j in range(n - i - 1):
        if arr[j] > arr[j + 1]:
          arr[j], arr[j + 1] = arr[j + 1], arr[j]

  return arr

# Contoh penggunaan
data = [64, 34, 25, 12, 22, 11, 90]
sorted_data = bubble_sort(data.copy()) # Menggunakan copy agar data asli tidak berubah
print("Data sebelum sorting:", data)
print("Data setelah Bubble Sort:", sorted_data)
# Out:
# Data sebelum sorting: [64, 34, 25, 12, 22, 11, 90]
# Data setelah Bubble Sort: [11, 12, 22, 25, 34, 64, 90]

# %% [markdown]
# Implementasi Selection Sort

# %%
def selection_sort(arr):
    n = len(arr)
    for i in range(n - 1):
        min_index = i
        for j in range(i + 1, n):
            if arr[j] < arr[min_index]:
                min_index = j
        arr[i], arr[min_index] = arr[min_index], arr[i]
    return arr

# Contoh penggunaan
data = [64, 25, 12, 22, 11]
sorted_data = selection_sort(data.copy())
print("Data sebelum sorting:", data)
print("Data setelah Selection Sort:", sorted_data)
# Out:
# Data sebelum sorting: [64, 25, 12, 22, 11]
# Data setelah Selection Sort: [11, 12, 22, 25, 64]

# %% [markdown]
# Implementasi Insertion Sort

# %%
def insertion_sort(arr):
    n = len(arr)
    for i in range(1, n):
        key = arr[i]
        j = i - 1
        while j >= 0 and arr[j] > key:
            arr[j + 1] = arr[j]
            j -= 1
        arr[j + 1] = key
    return arr

# Contoh penggunaan
data = [64, 34, 25, 12, 22, 11, 90]
sorted_data = insertion_sort(data.copy())
print("Data sebelum sorting:", data)
print("Data setelah Insertion Sort:", sorted_data)
# Out:
# Data sebelum sorting: [64, 34, 25, 12, 22, 11, 90]
# Data setelah Insertion Sort: [11, 12, 22, 25, 34, 64, 90]

# %% [markdown]
# Implementasi Merge Sort

# %%
def merge_sort(arr):
  if len(arr) > 1:
      mid = len(arr) // 2
      left_half = arr[:mid]
      right_half = arr[mid:]

      merge_sort(left_half)
      merge_sort(right_half)

      i = j = k = 0

      while i < len(left_half) and j < len(right_half):
          if left_half[i] < right_half[j]:
            arr[k] = left_half[i]
            i += 1
          else:
            arr[k] = right_half[j]
            j += 1
            k += 1

      while i < len(left_half):
           arr[k] = left_half[i]
           i += 1
           k += 1

      while j < len(right_half):
           arr[k] = right_half[j]
           j += 1
           k += 1

  return arr

# Contoh penggunaan
data = [64, 25, 12, 22, 11]
sorted_data = merge_sort(data.copy())
print("Data sebelum sorting:", data)
print("Data setelah Merge Sort:", sorted_data)
# Out:
# Data sebelum sorting: [64, 25, 12, 22, 11]
# Data setelah Merge Sort: [11, 22, 11, 25, 64]

# %% [markdown]
# Implementasi Quick Sort

# %%
def quick_sort(arr):
    if len(arr) <= 1:
       return arr

    pivot = arr[len(arr) // 2]
    left = [x for x in arr if x < pivot]
    middle = [x for x in arr if x == pivot]
    right = [x for x in arr if x > pivot]

    return quick_sort(left) + middle + quick_sort(right)

# Contoh penggunaan
data = [64, 25, 12, 22, 11]
sorted_data = quick_sort(data.copy())
print("Data sebelum sorting:", data)
print("Data setelah Quick Sort:", sorted_data)
# Out:
# Data sebelum sorting: [64, 25, 12, 22, 11]
# Data setelah Quick Sort: [11, 12, 22, 25, 64]

# %% [markdown]
# LATIHAN / TUGAS 6

# %%
# Data contoh: Daftar Film beserta Rating dan Jumlah Pemutaran
daftar_film = [
    {"judul": "Inception", "rating": 8.8, "pemutaran": 2500000},
    {"judul": "The Godfather", "rating": 9.2, "pemutaran": 1800000},
    {"judul": "Interstellar", "rating": 8.6, "pemutaran": 3200000},
    {"judul": "Parasite", "rating": 8.5, "pemutaran": 2100000},
    {"judul": "The Dark Knight", "rating": 9.0, "pemutaran": 2900000}
]

def tampilkan_rekomendasi(kriteria):
    print(f"\n--- Rekomendasi Berdasarkan {kriteria.capitalize()} ---")

    # Logika Pengurutan (Sorting)
    # reverse=True digunakan agar urutan dari yang terbesar ke terkecil
    if kriteria == "rating":
        sorted_list = sorted(daftar_film, key=lambda x: x['rating'], reverse=True)
    else:
        sorted_list = sorted(daftar_film, key=lambda x: x['pemutaran'], reverse=True)

    # Menampilkan hasil ke layar
    for i, film in enumerate(sorted_list, 1):
        print(f"{i}. {film['judul']} | Rating: {film['rating']} | Pemutaran: {film['pemutaran']:,}")

# Main Program
print("Selamat Datang di Platform Streaming (Rombel 04)")
print("Pilih kriteria rekomendasi:")
print("1. Rating Tertinggi")
print("2. Jumlah Pemutaran Terbanyak")

pilihan = input("Masukkan pilihan (1/2): ")

if pilihan == "1":
    tampilkan_rekomendasi("rating")
elif pilihan == "2":
    tampilkan_rekomendasi("pemutaran")
else:
    print("Pilihan tidak valid!")
# Out:
# Selamat Datang di Platform Streaming (Rombel 04)
# Pilih kriteria rekomendasi:
# 1. Rating Tertinggi
# 2. Jumlah Pemutaran Terbanyak
# Masukkan pilihan (1/2): 1
#
# --- Rekomendasi Berdasarkan Rating ---
# 1. The Godfather | Rating: 9.2 | Pemutaran: 1,800,000
# 2. The Dark Knight | Rating: 9.0 | Pemutaran: 2,900,000
# 3. Inception | Rating: 8.8 | Pemutaran: 2,500,000
# 4. Interstellar | Rating: 8.6 | Pemutaran: 3,200,000
# 5. Parasite | Rating: 8.5 | Pemutaran: 2,100,000
